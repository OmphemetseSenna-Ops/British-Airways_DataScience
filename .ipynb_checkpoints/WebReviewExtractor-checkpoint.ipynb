# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import time

# %%
# Define the CSV file path
csv_file = 'scraped_reviews2.csv'

# %%
def check_connection(url):
    """
    Check if we can establish a connection to the specified URL.

    Args:
    - url (str): The URL to check the connection.

    Returns:
    - bool: True if connection is successful, False otherwise.
    """
    try:
        response = requests.head(url)
        return response.status_code == 200
    except requests.ConnectionError:
        return False

# %%
def fetch_reviews(page_number, offset):
    """
    Fetch reviews from the airline quality website for a specific page number.
    
    Args:
    - page_number (int): The page number to fetch.
    - offset (int): The number of reviews to fetch per request.

    Returns:
    - list: A list of dictionaries containing the review data.
    """
    url = f"https://www.airlinequality.com/airline-reviews/ethiopian-airlines/page/{page_number}/?sortby=post_date%3ADesc&pagesize={offset}"
    
    print(f"Fetching reviews from page {page_number} with offset: {offset}.")
    
    try:
        # Send a GET request to fetch webpage content
        response = requests.get(url)
        response.raise_for_status()

        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        reviews = soup.find_all('article', itemprop='review')

        if not reviews:
            print("No reviews found on this page.")
            return []

        # Initialize a list to store extracted data
        data = []

        for review in reviews:
            rating = review.find('span', itemprop='ratingValue')
            rating = rating.text.strip() if rating else "N/A"

            author = review.find('span', itemprop='name')
            author = author.text.strip() if author else "N/A"

            heading_service = review.find('h2', class_='text_header')
            heading_service = heading_service.text.strip() if heading_service else "N/A"

            author_span = soup.find('span', itemprop='author')
            location_text = author_span.next_sibling.strip() if author_span else "N/A"

            date = review.find('time', itemprop='datePublished')
            date = date['datetime'] if date else "N/A"

            review_body = review.find('div', class_='text_content', itemprop='reviewBody')
            review_body = review_body.text.strip() if review_body else "N/A"

            # Initialize additional review details
            type_traveller = date_flown = seat_type = route = recommended = "N/A"
            seat_comfort = Cabin_Staff_Service = food_rating = entertainment_rating = ground_service_rating = value_for_money = "N/A"

            stats = review.find('div', class_='review-stats')
            if stats:
                rows = stats.find_all('tr')
                for row in rows:
                    header = row.find('td', class_='review-rating-header')
                    value = row.find('td', class_='review-value')
                    stars = row.find('td', class_='review-rating-stars stars')

                    if header:
                        header_text = header.text.strip().lower()
                        if "type of traveller" in header_text:
                            type_traveller = value.text.strip() if value else "N/A"
                        elif "seat type" in header_text:
                            seat_type = value.text.strip() if value else "N/A"
                        elif "route" in header_text:
                            route = value.text.strip() if value else "N/A"
                        elif "recommended" in header_text:
                            recommended = value.text.strip() if value else "N/A"
                        elif "date flown" in header_text:
                            date_flown = value.text.strip() if value else "N/A"

                        if stars:
                            star_count = len(stars.find_all('span', class_='star fill'))
                            if "food & beverages" in header_text:
                                food_rating = star_count
                            elif "inflight entertainment" in header_text:
                                entertainment_rating = star_count
                            elif "ground service" in header_text:
                                ground_service_rating = star_count
                            elif "value for money" in header_text:
                                value_for_money = star_count
                            elif "cabin staff service" in header_text:
                                Cabin_Staff_Service = star_count
                            elif "seat comfort" in header_text:
                                seat_comfort = star_count

            # Append extracted data to the list
            data.append({
                'Rating': rating,
                'Author': author,
                'Author Location': location_text,
                'Review Date': date,
                'Review Title': heading_service,
                'Review': review_body,
                'Type of Traveller': type_traveller,
                'Seat Type': seat_type,
                'Route': route,
                'Date Flown': date_flown,
                'Seat Comfort': seat_comfort,
                'Cabin Staff Service': Cabin_Staff_Service,
                'Food & Beverages': food_rating,
                'Inflight Entertainment': entertainment_rating,
                'Ground Service': ground_service_rating,
                'Value for Money': value_for_money,
                'Recommended Service': recommended
            })

        return data

    except requests.exceptions.RequestException as e:
        print(f"Error fetching page {page_number}: {e}")
        return []

# %%
def check_data_added_to_dataframe(reviews_df):
    """
    Check if data is added to the DataFrame and print the first 10 rows.

    Args:
    - reviews_df (DataFrame): The DataFrame to check.
    """
    if not reviews_df.empty:
        print("\nData has been successfully added to the DataFrame.")
        print("Here are the first 10 rows:")
        print(reviews_df.head(10))
    else:
        print("\nNo data has been added to the DataFrame.")

# %%
def perform_data_quality_checks(reviews_df, stage='Initial'):
    """
    Perform data quality checks on the DataFrame.

    Args:
    - reviews_df (DataFrame): The DataFrame to check.
    - stage (str): Stage of the data (Initial or After Cleaning).
    """
    print(f"\n--- Data Quality Checks at {stage} Stage ---")
    firstTen = reviews_df.head(10)
    print(firstTen)
    
    print("\n\nData Summary:")
    print(reviews_df.info())
    
    print("\n\nStatistical Summary:")
    print(reviews_df.describe())

    #  Check unique values in 'Date' and 'Date Flown' for diagnosis
    print(reviews_df['Date Flown'].unique())
    print(reviews_df['Review Date'].unique())

    # Check the shape of the DataFrame (number of rows and columns)
    numRows, numColumns = reviews_df.shape
    numCells = numRows * numColumns
    print(f'\nNumber of rows: {numRows} \nNumber of columns: {numColumns} \nTotal number of cells: {numCells}')

    # Check null values and Calculate the total number of null values
    nullValues = reviews_df.isnull().sum()
    totalNulls = nullValues.sum()
    print(f'\nTotal number of null values:\n{nullValues}')
    print(f'Total number of null values: {totalNulls}')

    # Check Duplicates
    checkDuplicates = reviews_df.duplicated().sum()
    print(f'Total number of duplicate rows: {checkDuplicates}')

# %%
def clean_data(reviews_df):
    """
    Clean the DataFrame containing review data.

    Args:
    - reviews_df (DataFrame): The DataFrame to clean.

    Returns:
    - DataFrame: The cleaned DataFrame.
    """

    # Convert relevant columns to numeric, coercing errors to NaN
    columns_to_convert = ['Rating', 'Food & Beverages', 'Inflight Entertainment', 
                          'Seat Comfort', 'Cabin Staff Service', 'Ground Service']
    for column in columns_to_convert:
        reviews_df[column] = pd.to_numeric(reviews_df[column], errors='coerce')

    # Fill NaN values with zeros
    reviews_df[columns_to_convert] = reviews_df[columns_to_convert].fillna(0)

    # Drop all rows with any null values initially
    reviews_df = reviews_df.dropna()

    # Format data from text to DateTime data type
    reviews_df['Date Flown'] = pd.to_datetime(reviews_df['Date Flown'], format='%B %Y', errors='coerce')
    reviews_df['Review Date'] = pd.to_datetime(reviews_df['Review Date'], errors='coerce')

    # Drop rows with NaT values in the date columns after conversion
    reviews_df = reviews_df.dropna(subset=['Date Flown', 'Review Date'])

    # Remove quotation marks
    reviews_df['Review Title'] = reviews_df['Review Title'].str.replace('“', '').str.replace('”', '').str.strip('"')
    reviews_df['Author Location'] = reviews_df['Author Location'].str.replace('(', '').str.replace(')', '').str.strip(')')

    # Remove duplicates based on certain criteria
    reviews_df.drop_duplicates(subset=['Author', 'Review'], keep='first', inplace=True)
    
    return reviews_df

# %%
def save_to_csv(data):
    """
    Save a cleaned DataFrame to a CSV file.

    Args:
    - data (DataFrame): The cleaned DataFrame to save.
    """
    if not data.empty:
        if os.path.exists(csv_file):
            data.to_csv(csv_file, mode='a', index=False, header=False)
        else:
            data.to_csv(csv_file, index=False)
        print(f"Saved {len(data)} reviews to '{csv_file}'.")
    else:
        print("No data to save.")

# %%
def main():
    url = 'https://www.airlinequality.com/airline-reviews/ethiopian-airlines/'
    if check_connection(url):
        print("Connection successful. Proceeding to fetch data...")
        all_reviews = []
        for i in range(1, 8):
            reviews_data = fetch_reviews(i, 100)
            all_reviews.extend(reviews_data)
            time.sleep(5)

        if all_reviews:
            reviews_df = pd.DataFrame(all_reviews)
            
            # Check if data is added to the DataFrame
            check_data_added_to_dataframe(reviews_df)

            # Perform initial data quality checks
            perform_data_quality_checks(reviews_df, stage='Initial')

            # Clean the data
            cleaned_df = clean_data(reviews_df)

            # Check if cleaned data is added to the DataFrame
            check_data_added_to_dataframe(cleaned_df)

            # Perform data quality checks after cleaning
            perform_data_quality_checks(cleaned_df, stage='After Cleaning')

            # Save the cleaned data to CSV
            save_to_csv(cleaned_df)

    else:
        print("Failed to connect to the URL. Please check your connection or URL.")

if __name__ == "__main__":
    main()
# Out:
# Connection successful. Proceeding to fetch data...
# Fetching reviews from page 1 with offset: 100.
# Fetching reviews from page 2 with offset: 100.
# Fetching reviews from page 3 with offset: 100.
# Fetching reviews from page 4 with offset: 100.
# Fetching reviews from page 5 with offset: 100.
# Fetching reviews from page 6 with offset: 100.
# Fetching reviews from page 7 with offset: 100.
#
# Data has been successfully added to the DataFrame.
# Here are the first 10 rows:
#   Rating           Author  Author Location        Date  \
# 0      1     Bart Johnson  (United States)  2025-01-05
# 1      2       H Thornton  (United States)  2025-01-03
# 2      3            I Lee  (United States)  2024-12-17
# 3      1      Brenda Acan  (United States)  2024-12-16
# 4      3  Jillian Saltpaw  (United States)  2024-12-15
# 5      1         E Basano  (United States)  2024-12-04
# 6      4         M Larsen  (United States)  2024-12-01
# 7      1          S Jiang  (United States)  2024-12-01
# 8      1        Gala Pate  (United States)  2024-11-29
# 9      4        R Adamski  (United States)  2024-11-01
#
#                                    Heading  \
# 0          "Not the best customer service"
# 1        “Worst business class experience”
# 2               "the toilets became dirty"
# 3                     “Worst service ever”
# 4           “service fell painfully short”
# 5  "Ethiopian Airlines needs to do better"
# 6     “I felt like I was back in the 90's”
# 7                     "expected much more"
# 8          “the most uncomfortable flight”
# 9  “didn’t like the flight or the service”
#
#                                               Review Type of Traveller  \
# 0  ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1  ✅ Trip Verified | Worst business class experie...          Business
# 2  ✅ Trip Verified |   Towards the end of the fli...          Business
# 3  ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4  ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5  ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6  ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7  ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8  Not Verified | It was the most uncomfortable f...    Family Leisure
# 9  ✅ Trip Verified | The staff had a rather avera...          Business
#
#         Seat Type                                        Route     Date Flown  \
# 0   Economy Class      Monrovia  to Washington via Addas Ababa   January 2025
# 1  Business Class              Addis Ababa to Toronto via Rome   January 2025
# 2   Economy Class                       Addis Ababa to Nairobi  December 2024
# 3   Economy Class               Dubai to Zanzibar via Ethiopia  December 2024
# 4   Economy Class               Washington IAD to Johannesburg  December 2024
# 5   Economy Class           Addis Ababa to Washington via Lome  November 2024
# 6   Economy Class           Hong Kong to Copenhagen via Luanda  November 2024
# 7   Economy Class                               Tokyo to Seoul  December 2024
# 8   Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa  December 2023
# 9  Business Class                         Hong Kong to Bangkok    August 2024
#
#   Seat Comfort Cabin Staff Service Food & Beverages Inflight Entertainment  \
# 0            1                   3                1                    N/A
# 1            2                   1                1                      1
# 2            1                   1                3                    N/A
# 3            1                   1                1                      1
# 4            2                   2                1                      3
# 5            2                   2                1                      1
# 6            2                   3                3                      2
# 7            2                   1                2                    N/A
# 8            1                   1                1                      1
# 9            3                   1                3                      3
#
#   Ground Service  Value for Money Recommended
# 0              2                2          no
# 1              2                3          no
# 2              3                3          no
# 3              1                1          no
# 4              1                1          no
# 5              2                1          no
# 6              2                3          no
# 7              5                1          no
# 8              1                1          no
# 9              3                3          no
#
# --- Data Quality Checks at Initial Stage ---
#   Rating           Author  Author Location        Date  \
# 0      1     Bart Johnson  (United States)  2025-01-05
# 1      2       H Thornton  (United States)  2025-01-03
# 2      3            I Lee  (United States)  2024-12-17
# 3      1      Brenda Acan  (United States)  2024-12-16
# 4      3  Jillian Saltpaw  (United States)  2024-12-15
# 5      1         E Basano  (United States)  2024-12-04
# 6      4         M Larsen  (United States)  2024-12-01
# 7      1          S Jiang  (United States)  2024-12-01
# 8      1        Gala Pate  (United States)  2024-11-29
# 9      4        R Adamski  (United States)  2024-11-01
#
#                                    Heading  \
# 0          "Not the best customer service"
# 1        “Worst business class experience”
# 2               "the toilets became dirty"
# 3                     “Worst service ever”
# 4           “service fell painfully short”
# 5  "Ethiopian Airlines needs to do better"
# 6     “I felt like I was back in the 90's”
# 7                     "expected much more"
# 8          “the most uncomfortable flight”
# 9  “didn’t like the flight or the service”
#
#                                               Review Type of Traveller  \
# 0  ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1  ✅ Trip Verified | Worst business class experie...          Business
# 2  ✅ Trip Verified |   Towards the end of the fli...          Business
# 3  ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4  ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5  ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6  ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7  ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8  Not Verified | It was the most uncomfortable f...    Family Leisure
# 9  ✅ Trip Verified | The staff had a rather avera...          Business
#
#         Seat Type                                        Route     Date Flown  \
# 0   Economy Class      Monrovia  to Washington via Addas Ababa   January 2025
# 1  Business Class              Addis Ababa to Toronto via Rome   January 2025
# 2   Economy Class                       Addis Ababa to Nairobi  December 2024
# 3   Economy Class               Dubai to Zanzibar via Ethiopia  December 2024
# 4   Economy Class               Washington IAD to Johannesburg  December 2024
# 5   Economy Class           Addis Ababa to Washington via Lome  November 2024
# 6   Economy Class           Hong Kong to Copenhagen via Luanda  November 2024
# 7   Economy Class                               Tokyo to Seoul  December 2024
# 8   Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa  December 2023
# 9  Business Class                         Hong Kong to Bangkok    August 2024
#
#   Seat Comfort Cabin Staff Service Food & Beverages Inflight Entertainment  \
# 0            1                   3                1                    N/A
# 1            2                   1                1                      1
# 2            1                   1                3                    N/A
# 3            1                   1                1                      1
# 4            2                   2                1                      3
# 5            2                   2                1                      1
# 6            2                   3                3                      2
# 7            2                   1                2                    N/A
# 8            1                   1                1                      1
# 9            3                   1                3                      3
#
#   Ground Service  Value for Money Recommended
# 0              2                2          no
# 1              2                3          no
# 2              3                3          no
# 3              1                1          no
# 4              1                1          no
# 5              2                1          no
# 6              2                3          no
# 7              5                1          no
# 8              1                1          no
# 9              3                3          no
#
#
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rating                  621 non-null    object
#  1   Author                  621 non-null    object
#  2   Author Location         621 non-null    object
#  3   Date                    621 non-null    object
#  4   Heading                 621 non-null    object
#  5   Review                  621 non-null    object
#  6   Type of Traveller       621 non-null    object
#  7   Seat Type               621 non-null    object
#  8   Route                   621 non-null    object
#  9   Date Flown              621 non-null    object
#  10  Seat Comfort            621 non-null    object
#  11  Cabin Staff Service     621 non-null    object
#  12  Food & Beverages        621 non-null    object
#  13  Inflight Entertainment  621 non-null    object
#  14  Ground Service          621 non-null    object
#  15  Value for Money         621 non-null    int64
#  16  Recommended             621 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 82.6+ KB
# None
#
#
# Statistical Summary:
#        Value for Money
# count       621.000000
# mean          2.805153
# std           1.550974
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# ['January 2025' 'December 2024' 'November 2024' 'December 2023'
#  'August 2024' 'September 2024' 'July 2024' 'June 2024' 'August 2023'
#  'February 2024' 'May 2024' 'April 2024' 'March 2024' 'January 2024'
#  'November 2023' 'September 2023' 'October 2023' 'July 2023' 'June 2023'
#  'May 2023' 'April 2023' 'March 2023' 'April 2022' 'February 2023'
#  'December 2022' 'October 2022' 'January 2023' 'November 2022'
#  'September 2022' 'August 2022' 'July 2022' 'June 2022' 'May 2022'
#  'December 2021' 'January 2022' 'March 2022' 'November 2021'
#  '2013-07-23' '2013-07-17' '2013-07-09' '2013-07-03' '2013-06-25'
#  '2013-06-21' '2013-06-16' '2013-06-13' '2013-06-02' '2013-05-29'
#  '2013-05-26' '2013-04-19' '2013-04-16' '2013-04-01' '2013-03-13'
#  '2013-02-27' '2013-02-26' '2013-02-25' '2013-01-29' '2013-01-24'
#  '2013-01-23' '2013-01-15' '2013-01-09' '2013-01-08' '2012-12-12'
#  '2012-12-10' '2012-11-27' '2012-11-15' '2012-11-06' '2012-10-18'
#  '2012-10-08' '2012-04-30' '2012-04-26' '2012-04-24' '2012-04-21'
#  '2012-04-20' '2012-04-16' '2012-04-08' '2012-04-04' '2012-03-22'
#  '2012-03-01' '2012-02-24' '2012-02-10' '2012-01-26' '2012-01-06'
#  '2012-01-04' '2011-12-30' '2011-12-28' '2011-12-14' '2011-12-13'
#  '2011-11-25' '2011-11-18' '2011-10-17' '2011-10-04' '2011-09-13'
#  '2011-09-11' '2011-09-05' '2011-09-01' '2011-08-30' '2011-02-23'
#  '2011-01-23' '2011-01-21' '2011-01-15' '2010-12-30' '2010-12-28'
#  '2010-12-27' '2010-12-14' '2010-10-30' '2010-10-22' '2010-10-15'
#  '2010-10-12' '2010-10-06' '2010-10-03' '2010-09-30' '2010-09-26'
#  '2010-09-19' '2010-08-28']
#
# Number of rows: 621
# Number of columns: 17
# Total number of cells: 10557
#
# Total number of null values:
# Rating                    0
# Author                    0
# Author Location           0
# Date                      0
# Heading                   0
# Review                    0
# Type of Traveller         0
# Seat Type                 0
# Route                     0
# Date Flown                0
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Inflight Entertainment    0
# Ground Service            0
# Value for Money           0
# Recommended               0
# dtype: int64
# Total number of null values: 0
# Total number of duplicate rows: 0
#
# Data has been successfully added to the DataFrame.
# Here are the first 10 rows:
#    Rating           Author Author Location       Date  \
# 0     1.0     Bart Johnson   United States 2025-01-05
# 1     2.0       H Thornton   United States 2025-01-03
# 2     3.0            I Lee   United States 2024-12-17
# 3     1.0      Brenda Acan   United States 2024-12-16
# 4     3.0  Jillian Saltpaw   United States 2024-12-15
# 5     1.0         E Basano   United States 2024-12-04
# 6     4.0         M Larsen   United States 2024-12-01
# 7     1.0          S Jiang   United States 2024-12-01
# 8     1.0        Gala Pate   United States 2024-11-29
# 9     4.0        R Adamski   United States 2024-11-01
#
#                                  Heading  \
# 0          Not the best customer service
# 1        Worst business class experience
# 2               the toilets became dirty
# 3                     Worst service ever
# 4           service fell painfully short
# 5  Ethiopian Airlines needs to do better
# 6     I felt like I was back in the 90's
# 7                     expected much more
# 8          the most uncomfortable flight
# 9  didn’t like the flight or the service
#
#                                               Review Type of Traveller  \
# 0  ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1  ✅ Trip Verified | Worst business class experie...          Business
# 2  ✅ Trip Verified |   Towards the end of the fli...          Business
# 3  ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4  ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5  ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6  ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7  ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8  Not Verified | It was the most uncomfortable f...    Family Leisure
# 9  ✅ Trip Verified | The staff had a rather avera...          Business
#
#         Seat Type                                        Route Date Flown  \
# 0   Economy Class      Monrovia  to Washington via Addas Ababa 2025-01-01
# 1  Business Class              Addis Ababa to Toronto via Rome 2025-01-01
# 2   Economy Class                       Addis Ababa to Nairobi 2024-12-01
# 3   Economy Class               Dubai to Zanzibar via Ethiopia 2024-12-01
# 4   Economy Class               Washington IAD to Johannesburg 2024-12-01
# 5   Economy Class           Addis Ababa to Washington via Lome 2024-11-01
# 6   Economy Class           Hong Kong to Copenhagen via Luanda 2024-11-01
# 7   Economy Class                               Tokyo to Seoul 2024-12-01
# 8   Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa 2023-12-01
# 9  Business Class                         Hong Kong to Bangkok 2024-08-01
#
#    Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0           1.0                  3.0               1.0
# 1           2.0                  1.0               1.0
# 2           1.0                  1.0               3.0
# 3           1.0                  1.0               1.0
# 4           2.0                  2.0               1.0
# 5           2.0                  2.0               1.0
# 6           2.0                  3.0               3.0
# 7           2.0                  1.0               2.0
# 8           1.0                  1.0               1.0
# 9           3.0                  1.0               3.0
#
#    Inflight Entertainment  Ground Service  Value for Money Recommended
# 0                     0.0             2.0                2          no
# 1                     1.0             2.0                3          no
# 2                     0.0             3.0                3          no
# 3                     1.0             1.0                1          no
# 4                     3.0             1.0                1          no
# 5                     1.0             2.0                1          no
# 6                     2.0             2.0                3          no
# 7                     0.0             5.0                1          no
# 8                     1.0             1.0                1          no
# 9                     3.0             3.0                3          no
#
# --- Data Quality Checks at After Cleaning Stage ---
#    Rating           Author Author Location       Date  \
# 0     1.0     Bart Johnson   United States 2025-01-05
# 1     2.0       H Thornton   United States 2025-01-03
# 2     3.0            I Lee   United States 2024-12-17
# 3     1.0      Brenda Acan   United States 2024-12-16
# 4     3.0  Jillian Saltpaw   United States 2024-12-15
# 5     1.0         E Basano   United States 2024-12-04
# 6     4.0         M Larsen   United States 2024-12-01
# 7     1.0          S Jiang   United States 2024-12-01
# 8     1.0        Gala Pate   United States 2024-11-29
# 9     4.0        R Adamski   United States 2024-11-01
#
#                                  Heading  \
# 0          Not the best customer service
# 1        Worst business class experience
# 2               the toilets became dirty
# 3                     Worst service ever
# 4           service fell painfully short
# 5  Ethiopian Airlines needs to do better
# 6     I felt like I was back in the 90's
# 7                     expected much more
# 8          the most uncomfortable flight
# 9  didn’t like the flight or the service
#
#                                               Review Type of Traveller  \
# 0  ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1  ✅ Trip Verified | Worst business class experie...          Business
# 2  ✅ Trip Verified |   Towards the end of the fli...          Business
# 3  ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4  ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5  ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6  ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7  ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8  Not Verified | It was the most uncomfortable f...    Family Leisure
# 9  ✅ Trip Verified | The staff had a rather avera...          Business
#
#         Seat Type                                        Route Date Flown  \
# 0   Economy Class      Monrovia  to Washington via Addas Ababa 2025-01-01
# 1  Business Class              Addis Ababa to Toronto via Rome 2025-01-01
# 2   Economy Class                       Addis Ababa to Nairobi 2024-12-01
# 3   Economy Class               Dubai to Zanzibar via Ethiopia 2024-12-01
# 4   Economy Class               Washington IAD to Johannesburg 2024-12-01
# 5   Economy Class           Addis Ababa to Washington via Lome 2024-11-01
# 6   Economy Class           Hong Kong to Copenhagen via Luanda 2024-11-01
# 7   Economy Class                               Tokyo to Seoul 2024-12-01
# 8   Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa 2023-12-01
# 9  Business Class                         Hong Kong to Bangkok 2024-08-01
#
#    Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0           1.0                  3.0               1.0
# 1           2.0                  1.0               1.0
# 2           1.0                  1.0               3.0
# 3           1.0                  1.0               1.0
# 4           2.0                  2.0               1.0
# 5           2.0                  2.0               1.0
# 6           2.0                  3.0               3.0
# 7           2.0                  1.0               2.0
# 8           1.0                  1.0               1.0
# 9           3.0                  1.0               3.0
#
#    Inflight Entertainment  Ground Service  Value for Money Recommended
# 0                     0.0             2.0                2          no
# 1                     1.0             2.0                3          no
# 2                     0.0             3.0                3          no
# 3                     1.0             1.0                1          no
# 4                     3.0             1.0                1          no
# 5                     1.0             2.0                1          no
# 6                     2.0             2.0                3          no
# 7                     0.0             5.0                1          no
# 8                     1.0             1.0                1          no
# 9                     3.0             3.0                3          no
#
#
# Data Summary:
# <class 'pandas.core.frame.DataFrame'>
# Index: 428 entries, 0 to 427
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rating                  428 non-null    float64
#  1   Author                  428 non-null    object
#  2   Author Location         428 non-null    object
#  3   Date                    428 non-null    datetime64[ns]
#  4   Heading                 428 non-null    object
#  5   Review                  428 non-null    object
#  6   Type of Traveller       428 non-null    object
#  7   Seat Type               428 non-null    object
#  8   Route                   428 non-null    object
#  9   Date Flown              428 non-null    datetime64[ns]
#  10  Seat Comfort            428 non-null    float64
#  11  Cabin Staff Service     428 non-null    float64
#  12  Food & Beverages        428 non-null    float64
#  13  Inflight Entertainment  428 non-null    float64
#  14  Ground Service          428 non-null    float64
#  15  Value for Money         428 non-null    int64
#  16  Recommended             428 non-null    object
# dtypes: datetime64[ns](2), float64(6), int64(1), object(8)
# memory usage: 60.2+ KB
# None
#
#
# Statistical Summary:
#            Rating                           Date  \
# count  428.000000                            428
# mean     4.182243  2019-09-10 16:29:09.532710400
# min      1.000000            2015-06-13 00:00:00
# 25%      1.000000            2017-04-12 18:00:00
# 50%      3.000000            2019-01-22 12:00:00
# 75%      7.000000            2022-07-15 18:00:00
# max     10.000000            2025-01-05 00:00:00
# std      3.249134                            NaN
#
#                           Date Flown  Seat Comfort  Cabin Staff Service  \
# count                            428    428.000000           428.000000
# mean   2019-07-31 11:16:15.700934656      2.600467             2.794393
# min              2015-01-01 00:00:00      0.000000             0.000000
# 25%              2017-03-01 00:00:00      1.000000             1.000000
# 50%              2018-12-01 00:00:00      3.000000             3.000000
# 75%              2022-06-08 12:00:00      4.000000             4.000000
# max              2025-01-01 00:00:00      5.000000             5.000000
# std                              NaN      1.506178             1.667928
#
#        Food & Beverages  Inflight Entertainment  Ground Service  \
# count        428.000000              428.000000      428.000000
# mean           2.390187                1.950935        2.264019
# min            0.000000                0.000000        0.000000
# 25%            1.000000                1.000000        1.000000
# 50%            2.000000                2.000000        2.000000
# 75%            4.000000                3.000000        4.000000
# max            5.000000                5.000000        5.000000
# std            1.613641                1.620976        1.518940
#
#        Value for Money
# count       428.000000
# mean          2.726636
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# std           1.589645
# <DatetimeArray>
# ['2025-01-01 00:00:00', '2024-12-01 00:00:00', '2024-11-01 00:00:00',
#  '2023-12-01 00:00:00', '2024-08-01 00:00:00', '2024-09-01 00:00:00',
#  '2024-07-01 00:00:00', '2024-06-01 00:00:00', '2023-08-01 00:00:00',
#  '2024-02-01 00:00:00',
#  ...
#  '2016-03-01 00:00:00', '2015-10-01 00:00:00', '2015-11-01 00:00:00',
#  '2015-09-01 00:00:00', '2015-08-01 00:00:00', '2015-06-01 00:00:00',
#  '2015-07-01 00:00:00', '2015-05-01 00:00:00', '2015-03-01 00:00:00',
#  '2015-01-01 00:00:00']
# Length: 111, dtype: datetime64[ns]
# <DatetimeArray>
# ['2025-01-05 00:00:00', '2025-01-03 00:00:00', '2024-12-17 00:00:00',
#  '2024-12-16 00:00:00', '2024-12-15 00:00:00', '2024-12-04 00:00:00',
#  '2024-12-01 00:00:00', '2024-11-29 00:00:00', '2024-11-01 00:00:00',
#  '2024-10-27 00:00:00',
#  ...
#  '2015-08-18 00:00:00', '2015-07-27 00:00:00', '2015-07-20 00:00:00',
#  '2015-07-16 00:00:00', '2015-07-05 00:00:00', '2015-07-02 00:00:00',
#  '2015-06-30 00:00:00', '2015-06-29 00:00:00', '2015-06-16 00:00:00',
#  '2015-06-13 00:00:00']
# Length: 390, dtype: datetime64[ns]
#
# Number of rows: 428
# Number of columns: 17
# Total number of cells: 7276
#
# Total number of null values:
# Rating                    0
# Author                    0
# Author Location           0
# Date                      0
# Heading                   0
# Review                    0
# Type of Traveller         0
# Seat Type                 0
# Route                     0
# Date Flown                0
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Inflight Entertainment    0
# Ground Service            0
# Value for Money           0
# Recommended               0
# dtype: int64
# Total number of null values: 0
# Total number of duplicate rows: 0
# Saved 428 reviews to 'scraped_reviews2.csv'.

# %%
import pandas as pd
import os

# %%
# File name of the CSV
fileName = 'scraped_reviews2.csv'

# %%
# Check if the file exists
if os.path.isfile(fileName):
    print(f"'{fileName}' does exist.") 
else:
    print(f"'{fileName}' does not exist.")
# Out:
# 'scraped_reviews2.csv' does exist.

# %%
#Read CSV file
OpenFile = pd.read_csv(fileName)
FirstTen = OpenFile.head(20)
FirstTen
# Out:
#     Rating                Author Author Location        Date  \
# 0      1.0          Bart Johnson   United States  2025-01-05
# 1      2.0            H Thornton   United States  2025-01-03
# 2      3.0                 I Lee   United States  2024-12-17
# 3      1.0           Brenda Acan   United States  2024-12-16
# 4      3.0       Jillian Saltpaw   United States  2024-12-15
# 5      1.0              E Basano   United States  2024-12-04
# 6      4.0              M Larsen   United States  2024-12-01
# 7      1.0               S Jiang   United States  2024-12-01
# 8      1.0             Gala Pate   United States  2024-11-29
# 9      4.0             R Adamski   United States  2024-11-01
# 10     1.0           Amadu Seidu   United States  2024-10-27
# 11    10.0   Annie Wegner LeFort   United States  2024-10-26
# 12     1.0  Ramon Van der Rassel   United States  2024-08-25
# 13    10.0             T Neumann   United States  2024-08-22
# 14     3.0               K Foard   United States  2024-08-07
# 15     2.0           Azhar Amine   United States  2024-08-02
# 16     1.0         Helen Osborne   United States  2024-07-24
# 17     1.0                 L Gan   United States  2024-06-21
# 18     4.0         Dr Caleb Moyo   United States  2024-06-20
# 19     1.0               E Thane   United States  2024-06-10
#
#                                   Heading  \
# 0           Not the best customer service
# 1         Worst business class experience
# 2                the toilets became dirty
# 3                      Worst service ever
# 4            service fell painfully short
# 5   Ethiopian Airlines needs to do better
# 6      I felt like I was back in the 90's
# 7                      expected much more
# 8           the most uncomfortable flight
# 9   didn’t like the flight or the service
# 10  appalling customer service experience
# 11        appreciative of his persistence
# 12              the most terrible company
# 13    staff very welcoming and supportive
# 14               airline is NEVER on time
# 15                did not load my luggage
# 16                     they won't respond
# 17           the luggage was never loaded
# 18           Luggage is never on schedule
# 19    Boeing 737 MAX 8 which is not ideal
#
#                                                Review Type of Traveller  \
# 0   ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1   ✅ Trip Verified | Worst business class experie...          Business
# 2   ✅ Trip Verified |   Towards the end of the fli...          Business
# 3   ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4   ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5   ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6   ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7   ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8   Not Verified | It was the most uncomfortable f...    Family Leisure
# 9   ✅ Trip Verified | The staff had a rather avera...          Business
# 10  Not Verified | Stranded, Ignored, and Betrayed...      Solo Leisure
# 11  Not Verified | Because of a very tight connect...      Solo Leisure
# 12  Not Verified |  I started my trip at Antananar...      Solo Leisure
# 13  Not Verified | As disclaimer, I am a big fan o...      Solo Leisure
# 14  Not Verified | This airline is NEVER on time. ...      Solo Leisure
# 15  Not Verified | They did not load my luggage de...      Solo Leisure
# 16  ✅ Trip Verified |  On their website they claim...      Solo Leisure
# 17  ✅ Trip Verified |  Our flight ET629 was delaye...      Solo Leisure
# 18  Not Verified | I lost part of luggage from the...    Family Leisure
# 19  ✅ Trip Verified |  I travel almost every weeke...          Business
#
#           Seat Type                                        Route  Date Flown  \
# 0     Economy Class      Monrovia  to Washington via Addas Ababa  2025-01-01
# 1    Business Class              Addis Ababa to Toronto via Rome  2025-01-01
# 2     Economy Class                       Addis Ababa to Nairobi  2024-12-01
# 3     Economy Class               Dubai to Zanzibar via Ethiopia  2024-12-01
# 4     Economy Class               Washington IAD to Johannesburg  2024-12-01
# 5     Economy Class           Addis Ababa to Washington via Lome  2024-11-01
# 6     Economy Class           Hong Kong to Copenhagen via Luanda  2024-11-01
# 7     Economy Class                               Tokyo to Seoul  2024-12-01
# 8     Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa  2023-12-01
# 9    Business Class                         Hong Kong to Bangkok  2024-08-01
# 10    Economy Class                    Accra to Atlanta via Bole  2024-08-01
# 11    Economy Class      Chicago to Johannesburg via Addis Ababa  2024-09-01
# 12    Economy Class     Antananarivo to Brussels via Addis Ababa  2024-08-01
# 13    Economy Class      Libreville to Frankfurt via Addis Ababa  2024-07-01
# 14    Economy Class                         Harar to Addis Ababa  2024-08-01
# 15  Premium Economy            London to Nairobi via Addis Ababa  2024-07-01
# 16    Economy Class         Cape Town to Gatwick via Addis Ababa  2024-07-01
# 17   Business Class            Bangkok to Kigali via Addis Adaba  2024-06-01
# 18    Economy Class            Bulawayo to Hamad via Addis Ababa  2023-08-01
# 19    Economy Class                  Addis Ababa to Johannesburg  2024-06-01
#
#     Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0            1.0                  3.0               1.0
# 1            2.0                  1.0               1.0
# 2            1.0                  1.0               3.0
# 3            1.0                  1.0               1.0
# 4            2.0                  2.0               1.0
# 5            2.0                  2.0               1.0
# 6            2.0                  3.0               3.0
# 7            2.0                  1.0               2.0
# 8            1.0                  1.0               1.0
# 9            3.0                  1.0               3.0
# 10           1.0                  1.0               0.0
# 11           5.0                  5.0               5.0
# 12           0.0                  0.0               0.0
# 13           4.0                  5.0               5.0
# 14           3.0                  4.0               2.0
# 15           3.0                  1.0               1.0
# 16           1.0                  1.0               1.0
# 17           2.0                  3.0               2.0
# 18           3.0                  4.0               2.0
# 19           1.0                  2.0               0.0
#
#     Inflight Entertainment  Ground Service  Value for Money Recommended
# 0                      0.0             2.0                2          no
# 1                      1.0             2.0                3          no
# 2                      0.0             3.0                3          no
# 3                      1.0             1.0                1          no
# 4                      3.0             1.0                1          no
# 5                      1.0             2.0                1          no
# 6                      2.0             2.0                3          no
# 7                      0.0             5.0                1          no
# 8                      1.0             1.0                1          no
# 9                      3.0             3.0                3          no
# 10                     0.0             1.0                1          no
# 11                     5.0             4.0                5         yes
# 12                     0.0             1.0                1          no
# 13                     3.0             5.0                5         yes
# 14                     1.0             2.0                2          no
# 15                     1.0             1.0                1          no
# 16                     1.0             1.0                1          no
# 17                     0.0             1.0                1          no
# 18                     1.0             2.0                5          no
# 19                     0.0             1.0                1          no
