# %%
import pyodbc
import pandas as pd

from sqlalchemy import create_engine
from urllib.parse import quote

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
# Define connection parameters
server = 'localhost'
database = 'BritishAirwaysDB'
driver = 'ODBC Driver 17 for SQL Server'

# Connection string
connection_string = f"mssql+pyodbc:///?odbc_connect={quote(f'DRIVER={{{driver}}};SERVER={server};DATABASE={database};Trusted_Connection=yes;')}"

try:
    # Establish a connection using pyodbc
    connection = pyodbc.connect(f'DRIVER={driver};SERVER={server};DATABASE={database};Trusted_Connection=yes;')
    print("Connected successfully to the database.")

    # Execute a simple query to ensure everything is working
    cursor = connection.cursor()
    cursor.execute("SELECT @@version;")
    row = cursor.fetchone()
    if row:
        print("Database version:", row[0])

except pyodbc.Error as e:
    print("Error in connection:", e)

finally:
    # Close the connection if it was established
    if 'connection' in locals() and connection:
        connection.close()

# Create a SQLAlchemy engine
engine = create_engine(connection_string)

# Query the table
query = "SELECT * FROM Reviews"
df = pd.read_sql(query, engine)
# Out:
# Connected successfully to the database.
# Database version: Microsoft SQL Server 2022 (RTM) - 16.0.1000.6 (X64)
# 	Oct  8 2022 05:58:25
# 	Copyright (C) 2022 Microsoft Corporation
# 	Developer Edition (64-bit) on Windows 10 Home Single Language 10.0 <X64> (Build 26100: ) (Hypervisor)

# %%
# Show First ten
OpenFile = df
FirstTen = OpenFile.head(10)
FirstTen
# Out:
#    Id  Rating           Author Author Location Review Date  \
# 0   1     1.0     Bart Johnson   United States  2025-01-05
# 1   2     2.0       H Thornton   United States  2025-01-03
# 2   3     3.0            I Lee   United States  2024-12-17
# 3   4     1.0      Brenda Acan   United States  2024-12-16
# 4   5     3.0  Jillian Saltpaw   United States  2024-12-15
# 5   6     1.0         E Basano   United States  2024-12-04
# 6   7     4.0         M Larsen   United States  2024-12-01
# 7   8     1.0          S Jiang   United States  2024-12-01
# 8   9     1.0        Gala Pate   United States  2024-11-29
# 9  10     4.0        R Adamski   United States  2024-11-01
#
#                             Review Title  \
# 0          Not the best customer service
# 1        Worst business class experience
# 2               the toilets became dirty
# 3                     Worst service ever
# 4           service fell painfully short
# 5  Ethiopian Airlines needs to do better
# 6     I felt like I was back in the 90's
# 7                     expected much more
# 8          the most uncomfortable flight
# 9  didn’t like the flight or the service
#
#                                               Review Type Of Traveller  \
# 0  ✅ Trip Verified |   Not the best customer serv...    Couple Leisure
# 1  ✅ Trip Verified | Worst business class experie...          Business
# 2  ✅ Trip Verified |   Towards the end of the fli...          Business
# 3  ✅ Trip Verified | Worst service ever. Beside d...    Couple Leisure
# 4  ✅ Trip Verified |   My recent journey from Was...    Couple Leisure
# 5  ✅ Trip Verified |   I just landed from an Ethi...      Solo Leisure
# 6  ✅ Trip Verified | HKG-BKK-ADD-LAD-ADD-VIE-CPH ...      Solo Leisure
# 7  ✅ Trip Verified |   Service was not there at a...    Couple Leisure
# 8  Not Verified | It was the most uncomfortable f...    Family Leisure
# 9  ✅ Trip Verified | The staff had a rather avera...          Business
#
#         Seat Type                                        Route Date Flown  \
# 0   Economy Class      Monrovia  to Washington via Addas Ababa 2025-01-01
# 1  Business Class              Addis Ababa to Toronto via Rome 2025-01-01
# 2   Economy Class                       Addis Ababa to Nairobi 2024-12-01
# 3   Economy Class               Dubai to Zanzibar via Ethiopia 2024-12-01
# 4   Economy Class               Washington IAD to Johannesburg 2024-12-01
# 5   Economy Class           Addis Ababa to Washington via Lome 2024-11-01
# 6   Economy Class           Hong Kong to Copenhagen via Luanda 2024-11-01
# 7   Economy Class                               Tokyo to Seoul 2024-12-01
# 8   Economy Class  Atlanta GA to Lusaka Zambia via Addis Ababa 2023-12-01
# 9  Business Class                         Hong Kong to Bangkok 2024-08-01
#
#    Seat Comfort  Cabin Staff Service  Food And Beverages  \
# 0           1.0                  3.0                 1.0
# 1           2.0                  1.0                 1.0
# 2           1.0                  1.0                 3.0
# 3           1.0                  1.0                 1.0
# 4           2.0                  2.0                 1.0
# 5           2.0                  2.0                 1.0
# 6           2.0                  3.0                 3.0
# 7           2.0                  1.0                 2.0
# 8           1.0                  1.0                 1.0
# 9           3.0                  1.0                 3.0
#
#    Inflight Entertainment  Ground Service  Value For Money Recommended Service
# 0                     0.0             2.0                2                  no
# 1                     1.0             2.0                3                  no
# 2                     0.0             3.0                3                  no
# 3                     1.0             1.0                1                  no
# 4                     3.0             1.0                1                  no
# 5                     1.0             2.0                1                  no
# 6                     2.0             2.0                3                  no
# 7                     0.0             5.0                1                  no
# 8                     1.0             1.0                1                  no
# 9                     3.0             3.0                3                  no

# %%
# Data Cleaning and Validation was done during ETL pipeline

# %%
# Prepare features and target

# %%
Service_Columns = ['Seat Comfort', 'Cabin Staff Service', 'Food And Beverages', 'Inflight Entertainment', 'Ground Service', 'Value For Money']

features = OpenFile[Service_Columns]
target = OpenFile['Recommended Service'].apply(lambda x: 1 if x.lower() == 'yes' else 0)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Model training
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Model prediction
predictions = model.predict(X_test)

# %%
# Performance metrics
report_dict = classification_report(y_test, predictions)
print(report_dict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        55
#            1       0.82      0.90      0.86        31
#
#     accuracy                           0.90        86
#    macro avg       0.88      0.90      0.89        86
# weighted avg       0.90      0.90      0.90        86

# %%
# Making predictions on the whole dataset or new instances
full_predictions = model.predict(features)

# %%
# Adding predictions to the original dataset for analysis
OpenFile['Predicted Recommended Service'] = full_predictions

# %%
# Display the updated dataset with predictions
print(OpenFile[['Id', 'Review Title', 'Predicted Recommended Service']])
# Out:
#       Id                        Review Title  Predicted Recommended Service
# 0      1       Not the best customer service                              0
# 1      2     Worst business class experience                              0
# 2      3            the toilets became dirty                              0
# 3      4                  Worst service ever                              0
# 4      5        service fell painfully short                              0
# ..   ...                                 ...                            ...
# 423  424  Ethiopian Airlines customer review                              0
# 424  425  Ethiopian Airlines customer review                              0
# 425  426  Ethiopian Airlines customer review                              0
# 426  427  Ethiopian Airlines customer review                              0
# 427  428  Ethiopian Airlines customer review                              1
#
# [428 rows x 3 columns]
